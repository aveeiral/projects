# %% [markdown]
# Note : Read the iphone.csv dataset to pandas dataframe
#
# 1 - The column names have spaces . rename the column names to have underscore '_' instead of space (try to do in one go instead of specifying each column nam in rename method)
#
# 2- start rating for some of the models is missing in the dataset. fill those missing values with the average rating all the models.
#
# 3- Now instead of filling missing values with avg rating of full dataset , fill with avg rating based on RAM. example :  if rating for a 2 gb phone is missing then take average of all other 2 gb phones rating and fill that value.
#
# 4- create a new column in the dataframe "Discount_Percentage" based on MRP and sale value
#
# 5- which model has highest percent discount ?
#
# 6- find total no of models  each space configuration (128 GB , 64 GB etc)
#
# 7- find total number of models for each color
#
# 8- find total number of models by iphone version : eg
# iphone 8:  9
# iphone XR : 5
#
# so on..
#
# 9- list top 5 models having highest no of reviews
#
# 10 - what is the price diffrence between highest price and lowest price iphone (based on mrp)
#
# 11 - find total no of reviews for iphone 11 and iphone 12 category . Output should have only 2 rows (for 11 and 12).
#
# 12- which iphone has 3rd highest MRP
#
# 13- what is the average mrp of iphones which costs above 100,000
#
# 14- which iphone with 128 GB space has highest ratings to review ratio

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/iphone.csv')
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Number Of Ratings  Number Of Reviews               Upc  \
# 0   49900               3431                356  MOBEXRGV7EHHTGUH
# 1   84900               3431                356  MOBEXRGVAC6TJT4F
# 2   84900               3431                356  MOBEXRGVGETABXWZ
# 3   77000              11202                794  MOBEXRGVMZWUHCBA
# 4   77000              11202                794  MOBEXRGVPK7PFEJZ
# ..    ...                ...                ...               ...
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 58  54900              43470               3331  MOBFWQ6BTFFJKGKE
# 59  54900              43470               3331  MOBFWQ6BVWVEH3XE
# 60  54900              43470               3331  MOBFWQ6BXGJCEYNY
# 61  54900              43470               3331  MOBFWQ6BYYV3FCU7
#
#     Star Rating   Ram
# 0           4.6  2 GB
# 1           4.6  2 GB
# 2           4.6  2 GB
# 3           NaN  2 GB
# 4           4.5  2 GB
# ..          ...   ...
# 57          4.5  4 GB
# 58          4.6  4 GB
# 59          4.6  4 GB
# 60          4.6  4 GB
# 61          4.6  4 GB
#
# [62 rows x 10 columns]

# %% [markdown]
# 1. The column names have spaces . rename the column names to have underscore '_' instead of space (try to do in one go instead of specifying each column nam in rename method)

# %%
col = df.columns
col
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Number Of Ratings', 'Number Of Reviews', 'Upc', 'Star Rating', 'Ram'],
#       dtype='object')

# %%
new_col = list(map(lambda x: x.replace(' ', '_'), col))
new_col
# Out:
# ['Product_Name',
#  'Product_URL',
#  'Brand',
#  'Sale_Price',
#  'Mrp',
#  'Number_Of_Ratings',
#  'Number_Of_Reviews',
#  'Upc',
#  'Star_Rating',
#  'Ram']

# %%
df.columns = new_col
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 0   49900               3431                356  MOBEXRGV7EHHTGUH
# 1   84900               3431                356  MOBEXRGVAC6TJT4F
# 2   84900               3431                356  MOBEXRGVGETABXWZ
# 3   77000              11202                794  MOBEXRGVMZWUHCBA
# 4   77000              11202                794  MOBEXRGVPK7PFEJZ
# ..    ...                ...                ...               ...
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 58  54900              43470               3331  MOBFWQ6BTFFJKGKE
# 59  54900              43470               3331  MOBFWQ6BVWVEH3XE
# 60  54900              43470               3331  MOBFWQ6BXGJCEYNY
# 61  54900              43470               3331  MOBFWQ6BYYV3FCU7
#
#     Star_Rating   Ram
# 0           4.6  2 GB
# 1           4.6  2 GB
# 2           4.6  2 GB
# 3           NaN  2 GB
# 4           4.5  2 GB
# ..          ...   ...
# 57          4.5  4 GB
# 58          4.6  4 GB
# 59          4.6  4 GB
# 60          4.6  4 GB
# 61          4.6  4 GB
#
# [62 rows x 10 columns]

# %% [markdown]
# 2. 2- start rating for some of the models is missing in the dataset. fill those missing values with the average rating all the models.

# %%
df['Star_Rating'] = round(df['Star_Rating'].fillna(df['Star_Rating'].mean()), 1)
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 0   49900               3431                356  MOBEXRGV7EHHTGUH
# 1   84900               3431                356  MOBEXRGVAC6TJT4F
# 2   84900               3431                356  MOBEXRGVGETABXWZ
# 3   77000              11202                794  MOBEXRGVMZWUHCBA
# 4   77000              11202                794  MOBEXRGVPK7PFEJZ
# ..    ...                ...                ...               ...
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 58  54900              43470               3331  MOBFWQ6BTFFJKGKE
# 59  54900              43470               3331  MOBFWQ6BVWVEH3XE
# 60  54900              43470               3331  MOBFWQ6BXGJCEYNY
# 61  54900              43470               3331  MOBFWQ6BYYV3FCU7
#
#     Star_Rating   Ram
# 0           4.6  2 GB
# 1           4.6  2 GB
# 2           4.6  2 GB
# 3           4.6  2 GB
# 4           4.5  2 GB
# ..          ...   ...
# 57          4.5  4 GB
# 58          4.6  4 GB
# 59          4.6  4 GB
# 60          4.6  4 GB
# 61          4.6  4 GB
#
# [62 rows x 10 columns]

# %% [markdown]
# 3- Now instead of filling missing values with avg rating of full dataset , fill with avg rating based on RAM. example : if rating for a 2 gb phone is missing then take average of all other 2 gb phones rating and fill that value.

# %%
ram_df = round(df.groupby('Ram', as_index=False)['Star_Rating'].mean(), 1)
ram_df = ram_df.set_index('Ram')
ram_df
abc = ram_df.loc['2 GB']['Star_Rating']
abc
#abc.values
# Out:
# 4.5

# %%
#np.isnan(df["Star_Rating"][0])
bac = df.loc[0]['Star_Rating']
bac
# Out:
# 4.6

# %%
for ind in df.index:
  if np.isnan(df[ind]['Star_Rating']):
    df.loc[ind]['Star_Rating'] = ram_df.loc[df.loc[ind]['Ram']]["Star_Rating"]
    #print(ram_df.loc[df.loc['Ram'][ind]]["Star_Rating"])
    #print(df.loc[ind]['Ram'])

# %%
print(df.value_counts())
# Out:
# Series([], dtype: int64)

# %% [markdown]
# 4- create a new column in the dataframe "Discount_Percentage" based on MRP and sale value

# %%
df["Discount_Percentage"] = round(((df["Mrp"] - df["Sale_Price"]) * 100)/(df["Mrp"]), 2)
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 0   49900               3431                356  MOBEXRGV7EHHTGUH
# 1   84900               3431                356  MOBEXRGVAC6TJT4F
# 2   84900               3431                356  MOBEXRGVGETABXWZ
# 3   77000              11202                794  MOBEXRGVMZWUHCBA
# 4   77000              11202                794  MOBEXRGVPK7PFEJZ
# ..    ...                ...                ...               ...
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 58  54900              43470               3331  MOBFWQ6BTFFJKGKE
# 59  54900              43470               3331  MOBFWQ6BVWVEH3XE
# 60  54900              43470               3331  MOBFWQ6BXGJCEYNY
# 61  54900              43470               3331  MOBFWQ6BYYV3FCU7
#
#     Star_Rating   Ram  Discount_Percentage
# 0           4.6  2 GB                 0.00
# 1           4.6  2 GB                 0.00
# 2           4.6  2 GB                 0.00
# 3           NaN  2 GB                 0.00
# 4           4.5  2 GB                 0.00
# ..          ...   ...                  ...
# 57          4.5  4 GB                24.81
# 58          4.6  4 GB                14.39
# 59          4.6  4 GB                14.39
# 60          4.6  4 GB                14.39
# 61          4.6  4 GB                14.39
#
# [62 rows x 11 columns]

# %% [markdown]
# 5- which model has highest percent discount ?

# %%
sorted_df = df.sort_values(by = 'Discount_Percentage', ascending = False)
sorted_df.head(1)
# Out:
#                                    Product_Name  \
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 18  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple       74999
#
#        Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 18  106600               7088                523  MOBFKCTSN3TG3RFJ
#
#     Star_Rating   Ram  Discount_Percentage
# 18          4.6  4 GB                29.64

# %% [markdown]
# 6- find total no of models each space configuration (128 GB , 64 GB etc)

# %%
# prompt: Make a new column Storage with only last 6 characters from Product_Name column

df['Storage'] = df['Product_Name'].apply(lambda x: x[-6:-1])
df['Storage_In_GB'] = df['Storage'].apply(lambda x: x[0:3])
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 0   49900               3431                356  MOBEXRGV7EHHTGUH
# 1   84900               3431                356  MOBEXRGVAC6TJT4F
# 2   84900               3431                356  MOBEXRGVGETABXWZ
# 3   77000              11202                794  MOBEXRGVMZWUHCBA
# 4   77000              11202                794  MOBEXRGVPK7PFEJZ
# ..    ...                ...                ...               ...
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 58  54900              43470               3331  MOBFWQ6BTFFJKGKE
# 59  54900              43470               3331  MOBFWQ6BVWVEH3XE
# 60  54900              43470               3331  MOBFWQ6BXGJCEYNY
# 61  54900              43470               3331  MOBFWQ6BYYV3FCU7
#
#     Star_Rating   Ram  Discount_Percentage Storage     Colour  \
# 0           4.6  2 GB                 0.00   64 GB  lus (Gold
# 1           4.6  2 GB                 0.00   56 GB  ace Grey,
# 2           4.6  2 GB                 0.00   56 GB   (Silver,
# 3           NaN  2 GB                 0.00   56 GB   (Silver,
# 4           4.5  2 GB                 0.00   56 GB   8 (Gold,
# ..          ...   ...                  ...     ...        ...
# 57          4.5  4 GB                24.81   64 GB  SE (Black
# 58          4.6  4 GB                14.39   64 GB  1 (Purple
# 59          4.6  4 GB                14.39   64 GB  11 (White
# 60          4.6  4 GB                14.39   64 GB  11 (Black
# 61          4.6  4 GB                14.39   64 GB  e 11 (Red
#
#             version Storage_In_GB
# 0   APPLE iPhone 8            64
# 1   APPLE iPhone 8            56
# 2   APPLE iPhone 8            56
# 3   APPLE iPhone 8            56
# 4   APPLE iPhone 8            56
# ..              ...           ...
# 57  APPLE iPhone SE           64
# 58  APPLE iPhone 11           64
# 59  APPLE iPhone 11           64
# 60  APPLE iPhone 11           64
# 61  APPLE iPhone 11           64
#
# [62 rows x 15 columns]

# %%
storage_count = df['Storage'].value_counts()
storage_count = storage_count.reset_index()
storage_count.columns = ['Storage', 'Value']
storage_count
# Out:
#   Storage  Value
# 0   28 GB     24
# 1   64 GB     20
# 2   56 GB     14
# 3   12 GB      4

# %% [markdown]
# 7- find total number of models for each color

# %%
#df['Colour'] = df['Product_Name'].apply(lambda x: x[-17:-4])
#df['Colour'] = df['Colour'].apply(lambda x: x[0:-4])
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4   https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
# ..                                                ...    ...         ...
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       46999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       46999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       46999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       46999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 0   49900               3431                356  MOBEXRGV7EHHTGUH
# 1   84900               3431                356  MOBEXRGVAC6TJT4F
# 2   84900               3431                356  MOBEXRGVGETABXWZ
# 3   77000              11202                794  MOBEXRGVMZWUHCBA
# 4   77000              11202                794  MOBEXRGVPK7PFEJZ
# ..    ...                ...                ...               ...
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 58  54900              43470               3331  MOBFWQ6BTFFJKGKE
# 59  54900              43470               3331  MOBFWQ6BVWVEH3XE
# 60  54900              43470               3331  MOBFWQ6BXGJCEYNY
# 61  54900              43470               3331  MOBFWQ6BYYV3FCU7
#
#     Star_Rating   Ram  Discount_Percentage Storage     Colour
# 0           4.6  2 GB                 0.00   64 GB  lus (Gold
# 1           4.6  2 GB                 0.00   56 GB  ace Grey,
# 2           4.6  2 GB                 0.00   56 GB   (Silver,
# 3           NaN  2 GB                 0.00   56 GB   (Silver,
# 4           4.5  2 GB                 0.00   56 GB   8 (Gold,
# ..          ...   ...                  ...     ...        ...
# 57          4.5  4 GB                24.81   64 GB  SE (Black
# 58          4.6  4 GB                14.39   64 GB  1 (Purple
# 59          4.6  4 GB                14.39   64 GB  11 (White
# 60          4.6  4 GB                14.39   64 GB  11 (Black
# 61          4.6  4 GB                14.39   64 GB  e 11 (Red
#
# [62 rows x 13 columns]

# %%
df['Colour'].value_counts()

# %% [markdown]
# 8- find total number of models by iphone version : eg
# iphone 8:  9
# iphone XR : 5

# %%
df['version'] = df['Product_Name'].apply(lambda x: x[0:15])
vers = df['version'].value_counts().reset_index()
vers.columns = ['Model', 'Value']
vers

#df['Colour'] = df['Colour'].apply(lambda x: x[0:-4])
# Out:
#              Model  Value
# 0  APPLE iPhone 12     26
# 1  APPLE iPhone 11     16
# 2  APPLE iPhone 8       8
# 3  Apple iPhone XR      5
# 4  APPLE iPhone SE      5
# 5  APPLE iPhone XS      1
# 6  Apple iPhone SE      1

# %% [markdown]
# 9- list top 5 models having highest no of reviews

# %%
df_sorted = df.sort_values(by='Number_Of_Reviews', ascending=False)
df_sorted.head(5)
# Out:
#                        Product_Name  \
# 23  Apple iPhone SE (White, 256 GB)
# 53  APPLE iPhone SE (Black, 128 GB)
# 55    APPLE iPhone SE (Red, 128 GB)
# 57   APPLE iPhone SE (Black, 64 GB)
# 52   APPLE iPhone SE (White, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 23  https://www.flipkart.com/apple-iphone-se-white...  Apple       44999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
#
#       Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 23  54900              95909               8161  MOBFRFXHPZCHAPEH
# 53  44900              95909               8161  MOBFWQ6BHUEVZPXD
# 55  44900              95909               8161  MOBFWQ6BJTVFKPEJ
# 57  39900              95909               8161  MOBFWQ6BR3MK7AUG
# 52  39900              95807               8154  MOBFWQ6BGWDVGF3E
#
#     Star_Rating   Ram  Discount_Percentage Storage     Colour          version
# 23          4.5  2 GB                18.03   56 GB  E (White,  Apple iPhone SE
# 53          4.5  2 GB                22.05   28 GB  E (Black,  APPLE iPhone SE
# 55          4.5  2 GB                22.05   28 GB   SE (Red,  APPLE iPhone SE
# 57          4.5  4 GB                24.81   64 GB  SE (Black  APPLE iPhone SE
# 52          4.5  2 GB                24.81   64 GB  SE (White  APPLE iPhone SE

# %% [markdown]
# 10 - what is the price diffrence between highest price and lowest price iphone (based on mrp)

# %%
difference = df['Mrp'].max() - df["Mrp"].min()
difference
# Out:
# 110000

# %% [markdown]
# 11 - find total no of reviews for iphone 11 and iphone 12 category . Output should have only 2 rows (for 11 and 12).

# %%
df
ip11 = df['version'].str.contains('APPLE iPhone 11')
ip12 = df['version'].str.contains('APPLE iPhone 12')
ip11_val = df[ip11]['Number_Of_Reviews'].sum()
ip12_val = df[ip12]['Number_Of_Reviews'].sum()
cat_review = {'Model': ['APPLE iPhone 11', 'APPLE iPhone 12'] , 'Number Of Reviews': [ip11_val, ip12_val]}
cat_df = pd.DataFrame(cat_review)
cat_df
# Out:
#              Model  Number Of Reviews
# 0  APPLE iPhone 11              25965
# 1  APPLE iPhone 12               2208

# %% [markdown]
# 12- which iphone has 3rd highest MRP

# %%
df_sortmrp = df.sort_values('Mrp', ascending = False)
df_sortmrp.head(3).tail(1)
# Out:
#                                     Product_Name  \
# 21  APPLE iPhone 11 Pro (Midnight Green, 512 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 21  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple      117900
#
#        Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 21  140300               7088                523  MOBFKCTSSJCWYGCC
#
#     Star_Rating   Ram  Discount_Percentage Storage     Colour          version
# 21          4.6  4 GB                15.97   12 GB  ht Green,  APPLE iPhone 11

# %% [markdown]
# 13- what is the average mrp of iphones which costs above 100,000

# %%
average = df['Mrp'] > 100000
avg = df[average]['Mrp'].mean()
avg
# Out:
# 130559.09090909091

# %% [markdown]
# 14- which iphone with 128 GB space has highest ratings to review ratio

# %%
df
df['Storage_In_GB'].value_counts()
#con_col = (df['Storage_In_GB'] == 128)
# no Phone with 128 GB Storage
# Out:
# 28     24
# 64     20
# 56     14
# 12      4
# Name: Storage_In_GB, dtype: int64
